# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Rabithah Zahiratus S\TA

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.dummy_module import say_hello, add_numbers, SKRIPSI_NAME

print(say_hello("Salwa"))
print(add_numbers(40, 53))
print(SKRIPSI_NAME)
# Out:
# Halo Salwa, import-mu berhasil! 🎉
# 93
# Temporal Topic Modeling Banking Superapp

# %%
from utils.dummy_module import say_hello
say_hello("Salwa")
# Out:
# 'Halo Salwa, import-mu berhasil! 🎉'

# %%
say_hello("Salwa")
# Out:
# 'Halo Salwa, AUTORELOAD WORKS! 🪄'
